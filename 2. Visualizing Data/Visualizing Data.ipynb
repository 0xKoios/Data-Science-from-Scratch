# %% [markdown]
# # Matplotlib
#
# ![logo2_compressed.svg](attachment:logo2_compressed.svg)
#
# ในการทำ **visualizing data** มี tools หรือ library หลายตัวมากที่สามารถนำมาใช้งานได้ แต่ใน repo นี้ผมจะใช้ library **matplotlib** เป็นหลัก
# และในการ plot กราฟผมจะใช้ module `matplotlib.pyplot` ในการ plot
#
# ## เหตุผลที่เราต้องทำ visualizing data มี 2 ข้อคือ:
#
#     - To explore data
#     - To communicate data

# %% [markdown]
# ---

# %% [markdown]
# ## Install matplotlib
#
# **matplotlib** ไม่ได้เป็น core library ของ **Python** ดังนั้นเราจึงต้องทำการติดตั้งเพิ่มโดยใช้คำสั่งด้านใน code cell ด้านล่าง
#
# `pip install matplotlib`
#
# หลังจากที่ติดตั้งเสร็จเรียบร้อยแล้ว เราต้องทำการ ***import matplotlib*** มาใช้งาน

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# หรือสามารถ import แบบนี้ก็ได้เช่นกัน

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## Simple plots

# %%
years = np.arange(1950, 2011, 10)
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color="green", marker="o", linestyle="solid")

# add a titile
plt.title("Nominal GDP") 

# add a label to the y-axis
plt.ylabel("Billions of $")
plt.show()
